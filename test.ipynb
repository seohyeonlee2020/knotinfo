# %%
import pandas as pd

snappy_db = pd.read_csv('/Users/seohyeonlee/Downloads/ribbon_links.csv')

# %%
snappy_db.shape

snappy_db.describe()

snappy_db[:10]
# Out:
#    id                  name  cusps  betti torsion     volume   chernsimons  \
# 0   0  ribbon_2_12_4118336d      2      2      []  12.569466 -2.367965e-01
# 1   1  ribbon_2_12_2522b6b3      2      2      []  13.144468 -1.231491e-64
# 2   2  ribbon_2_14_c532d28f      2      2      []  18.016320  2.316200e-01
# 3   3  ribbon_2_14_65f6cebc      2      2      []  17.994704  2.847822e-64
# 4   4  ribbon_2_10_7ecd0dc0      2      2      []   7.327725  1.202628e-65
# 5   5  ribbon_2_14_be8fa555      2      2      []  15.016387  2.313154e-01
# 6   6  ribbon_2_13_5d43499e      2      2      []  15.126631  2.332113e-01
# 7   7  ribbon_2_10_dc42cb6a      2      2      []   7.327725  2.500000e-01
# 8   8  ribbon_2_14_473214b5      2      2      []  11.652116  2.500000e-01
# 9   9  ribbon_2_26_1685dc04      2      2      []  21.849296 -4.158045e-02
#
#    tets                              hash  \
# 0    16  7ea34b60b6b1d89c6ee22e27cbcab888
# 1    14  a697de8841b006626e48f0c496654784
# ...
